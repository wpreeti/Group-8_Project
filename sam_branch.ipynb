# %%
# import dependancies 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Path to CPI csv file, load in and read CPI data 
hpi_file = r"C:\Users\Sam Song\Desktop\Data Analytics Bootcamp\Project 1\Group-8_Project\Resources\Master_HPI_data.csv"


hpi_df = pd.read_csv(hpi_file)
hpi_df
# Out:
#              hpi_type     hpi_flavor  frequency                   level  \
# 0         traditional  purchase-only    monthly  USA or Census Division
# 1         traditional  purchase-only    monthly  USA or Census Division
# 2         traditional  purchase-only    monthly  USA or Census Division
# 3         traditional  purchase-only    monthly  USA or Census Division
# 4         traditional  purchase-only    monthly  USA or Census Division
# ...               ...            ...        ...                     ...
# 120646  developmental  purchase-only  quarterly             Puerto Rico
# 120647  developmental  purchase-only  quarterly             Puerto Rico
# 120648  developmental  purchase-only  quarterly             Puerto Rico
# 120649  developmental  purchase-only  quarterly             Puerto Rico
# 120650  developmental  purchase-only  quarterly             Puerto Rico
#
#                          place_name place_id    yr  period  index_nsa  \
# ...

# %%
# Rename column headers
renamed_hpi_df = hpi_df.rename(columns={'hpi_type': 'HPI Type', 
                                        'hpi_flavor': 'HPI Flavor', 
                                        'frequency': 'Frequency', 
                                        'level': 'Level', 
                                        'place_name': 'Place Name',
                                        'place_id': 'Place ID', 
                                        'yr': 'Year', 
                                        'period': 'Period', 
                                        'index_nsa': 'Index (NSA)', 
                                        'index_sa': 'Index (SA)'})

renamed_hpi_df
# Out:
#              HPI Type     HPI Flavor  Frequency                   Level  \
# 0         traditional  purchase-only    monthly  USA or Census Division
# 1         traditional  purchase-only    monthly  USA or Census Division
# 2         traditional  purchase-only    monthly  USA or Census Division
# 3         traditional  purchase-only    monthly  USA or Census Division
# 4         traditional  purchase-only    monthly  USA or Census Division
# ...               ...            ...        ...                     ...
# 120646  developmental  purchase-only  quarterly             Puerto Rico
# 120647  developmental  purchase-only  quarterly             Puerto Rico
# 120648  developmental  purchase-only  quarterly             Puerto Rico
# 120649  developmental  purchase-only  quarterly             Puerto Rico
# 120650  developmental  purchase-only  quarterly             Puerto Rico
#
#                          Place Name Place ID  Year  Period  Index (NSA)  \
# ...

# %%
# Display only data for the U.S. and Census Divisions (monthly data)
monthly_hpi = renamed_hpi_df.loc[renamed_hpi_df['Frequency'] == 'monthly', :]
monthly_hpi
# Out:
#          HPI Type     HPI Flavor Frequency                   Level  \
# 0     traditional  purchase-only   monthly  USA or Census Division
# 1     traditional  purchase-only   monthly  USA or Census Division
# 2     traditional  purchase-only   monthly  USA or Census Division
# 3     traditional  purchase-only   monthly  USA or Census Division
# 4     traditional  purchase-only   monthly  USA or Census Division
# ...           ...            ...       ...                     ...
# 3825  traditional  purchase-only   monthly  USA or Census Division
# 3826  traditional  purchase-only   monthly  USA or Census Division
# 3827  traditional  purchase-only   monthly  USA or Census Division
# 3828  traditional  purchase-only   monthly  USA or Census Division
# 3829  traditional  purchase-only   monthly  USA or Census Division
#
#                        Place Name Place ID  Year  Period  Index (NSA)  \
# 0     East North Central Division   DV_ENC  1991       1       100.00
# ...

# %%
# Exlcude HPI Type, Flavor, Frequency, Level of Geography, Place ID; All unneccessary for analysis
# Include only seasonally adjusted data
clean_monthly_df = monthly_hpi[['Place Name', 'Year', 'Period', 'Index (SA)']]
clean_monthly_df
# Out:
#                        Place Name  Year  Period  Index (SA)
# 0     East North Central Division  1991       1      100.00
# 1     East North Central Division  1991       2      100.97
# 2     East North Central Division  1991       3      100.91
# 3     East North Central Division  1991       4      100.99
# 4     East North Central Division  1991       5      101.37
# ...                           ...   ...     ...         ...
# 3825                United States  2022       7      394.40
# 3826                United States  2022       8      392.18
# 3827                United States  2022       9      392.77
# 3828                United States  2022      10      392.78
# 3829                United States  2022      11      392.26
#
# [3830 rows x 4 columns]

# %%
clean_monthly_df['Index (SA) % Change'] = clean_monthly_df['Index (SA)'].pct_change()
clean_monthly_df
# Out:
# C:\Users\Sam Song\AppData\Local\Temp\ipykernel_21264\642446290.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_monthly_df['Index (SA) % Change'] = clean_monthly_df['Index (SA)'].pct_change()
#                        Place Name  Year  Period  Index (SA)  \
# 0     East North Central Division  1991       1      100.00
# 1     East North Central Division  1991       2      100.97
# 2     East North Central Division  1991       3      100.91
# 3     East North Central Division  1991       4      100.99
# 4     East North Central Division  1991       5      101.37
# ...                           ...   ...     ...         ...
# 3825                United States  2022       7      394.40
# ...

# %%
clean_monthly_df = clean_monthly_df.loc[clean_monthly_df["Period"] == 1]
clean_monthly_df
# Out:
#                        Place Name  Year  Period  Index (SA)  \
# 0     East North Central Division  1991       1      100.00
# 12    East North Central Division  1992       1      103.88
# 24    East North Central Division  1993       1      108.54
# 36    East North Central Division  1994       1      114.16
# 48    East North Central Division  1995       1      119.32
# ...                           ...   ...     ...         ...
# 3771                United States  2018       1      251.50
# 3783                United States  2019       1      264.93
# 3795                United States  2020       1      280.76
# 3807                United States  2021       1      315.28
# 3819                United States  2022       1      373.13
#
#       Index (SA) % Change
# 0                     NaN
# 12               0.004545
# 24               0.001199
# 36               0.006170
# 48               0.006325
# ...                   ...
# 3771             0.007088
# ...

# %%
# checking for all unique regions
(clean_monthly_df["Place Name"].unique())
# Out:
# array(['East North Central Division', 'East South Central Division',
#        'Middle Atlantic Division', 'Mountain Division',
#        'New England Division', 'Pacific Division',
#        'South Atlantic Division', 'West North Central Division',
#        'West South Central Division', 'United States'], dtype=object)

# %%
final_df = clean_monthly_df
final_df
# Out:
#                        Place Name  Year  Period  Index (SA)  \
# 0     East North Central Division  1991       1      100.00
# 12    East North Central Division  1992       1      103.88
# 24    East North Central Division  1993       1      108.54
# 36    East North Central Division  1994       1      114.16
# 48    East North Central Division  1995       1      119.32
# ...                           ...   ...     ...         ...
# 3771                United States  2018       1      251.50
# 3783                United States  2019       1      264.93
# 3795                United States  2020       1      280.76
# 3807                United States  2021       1      315.28
# 3819                United States  2022       1      373.13
#
#       Index (SA) % Change
# 0                     NaN
# 12               0.004545
# 24               0.001199
# 36               0.006170
# 48               0.006325
# ...                   ...
# 3771             0.007088
# ...

# %%
# Push the remade DataFrame to a new CSV file
final_df.to_csv('../Group-8_Project/Resources/sam_final_df', index= False, encoding='utf-8')

# %%
# Create dataframes for every region 

east_north_central = clean_monthly_df.loc[clean_monthly_df['Place Name'] == 'East North Central Division']
east_south_central = clean_monthly_df.loc[clean_monthly_df['Place Name'] == 'East South Central Division']
middle_atlantic_division = clean_monthly_df.loc[clean_monthly_df['Place Name'] == 'Middle Atlantic Division']
mountain_division = clean_monthly_df.loc[clean_monthly_df['Place Name'] == 'Mountain Division']
new_england_division = clean_monthly_df.loc[clean_monthly_df['Place Name'] == 'New England Division']
pacific_division = clean_monthly_df.loc[clean_monthly_df['Place Name'] == 'Pacific Division']
south_atlantic_division = clean_monthly_df.loc[clean_monthly_df['Place Name'] == 'South Atlantic Division']
west_north_central_division = clean_monthly_df.loc[clean_monthly_df['Place Name'] == 'West North Central Division']
west_south_central_division = clean_monthly_df.loc[clean_monthly_df['Place Name'] == 'West South Central Division']

east_north_central.head()
# Out:
#                      Place Name  Year  Period  Index (SA)  Index (SA) % Change
# 0   East North Central Division  1991       1      100.00                  NaN
# 12  East North Central Division  1992       1      103.88             0.004545
# 24  East North Central Division  1993       1      108.54             0.001199
# 36  East North Central Division  1994       1      114.16             0.006170
# 48  East North Central Division  1995       1      119.32             0.006325

# %%
# convert df column values into array for visualization 
years = east_north_central['Year'].to_numpy()
east_north =  east_north_central['Index (SA)'].to_numpy()
east_south = east_south_central['Index (SA)'].to_numpy()
middle_atlantic = middle_atlantic_division['Index (SA)'].to_numpy()
mountain = mountain_division['Index (SA)'].to_numpy()
new_england = new_england_division['Index (SA)'].to_numpy()
pacific = pacific_division['Index (SA)'].to_numpy()
south_atlantic = south_atlantic_division['Index (SA)'].to_numpy()
west_north_central = west_north_central_division['Index (SA)'].to_numpy()
west_south_central = west_south_central_division['Index (SA)'].to_numpy()

# plot the data
visualization_df = pd.DataFrame({
   'East North Central': east_north,
   'East South Central': east_south,
   'Middle Atlantic': middle_atlantic,
   'Mountain': mountain,
   'New England': new_england,
   'Pacific': pacific,
   'South Atlantic': south_atlantic,
   'West North Central': west_north_central,
   'West South Central': west_south_central,
},  index= years)

line_plot = visualization_df.plot.line()
line_plot.set_xlabel("Years")
line_plot.set_ylabel("HPI")
# Out:
# Text(0, 0.5, 'HPI')
